# %%
# PART 1 - Dataset Understanding (5 questions)
# 1.Import the pandas library.
# !pip install pandas

# %%
# 2.Load the Dataset into a DataFrame .
import pandas as pd
df=pd.read_csv('/content/online_shopping_uncleaned_20000_rows (1).csv')

# %%
# 3. Display the First 10 Rows.
df.head()
# Out:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
# 3           3     17850.0      M  Chicago           12.0         16699.0
# 4           4     17850.0      M  Chicago           12.0         16700.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Product_Category  ...  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA  ...
# ...

# %%
# 4.Display the Last 10 Rows
df.tail()
# Out:
#        Unnamed: 0  CustomerID Gender       Location  Tenure_Months  \
# 19995       19995     13854.0      F        Chicago           44.0
# 19996       19996     13854.0      F        Chicago           44.0
# 19997       19997     17790.0      F  Washington DC           34.0
# 19998       19998     12370.0      F       New York           21.0
# 19999       19999     17404.0      F     New Jersey           11.0
#
#        Transaction_ID Transaction_Date     Product_SKU  \
# 19995         31174.0       2019-06-25  GGOEGFKA022299
# 19996         31174.0       2019-06-25  GGOEGGOA017399
# 19997         31203.0       2019-06-25  GGOEYFKQ020699
# 19998         31175.0       2019-06-25  GGOEGFKQ020399
# 19999         31214.0       2019-06-25  GGOEGFKQ020399
#
#                          Product_Description Product_Category  ...  \
# 19995                   Keyboard DOT Sticker           Office  ...
# 19996                               Maze Pen           Office  ...
# ...

# %%
# 5.Find thw total Number of Rows and Columns.
df.shape
# Out:
# (20000, 30)

# %%
# PART-2 Data Exploration(5 questions)
# 6. Display all Columns names
df.columns
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'Gender', 'Location', 'Tenure_Months',
#        'Transaction_ID', 'Transaction_Date', 'Product_SKU',
#        'Product_Description', 'Product_Category', 'Quantity', 'Avg_Price',
#        'Delivery_Charges', 'Coupon_Status', 'GST', 'Date', 'Offline_Spend',
#        'Online_Spend', 'Month', 'Coupon_Code', 'Discount_pct',
#        'Payment_Status', 'Delivery_Days', 'Customer_Rating', 'Return_Status',
#        'Customer_City', 'Discount_Percent', 'Order_Priority', 'Support_Calls',
#        'Membership'],
#       dtype='object')

# %%
# 7. Check data type  od each columns
df.dtypes
# Out:
# Unnamed: 0               int64
# CustomerID             float64
# Gender                  object
# Location                object
# Tenure_Months          float64
# Transaction_ID         float64
# Transaction_Date        object
# Product_SKU             object
# Product_Description     object
# Product_Category        object
# Quantity               float64
# Avg_Price              float64
# Delivery_Charges       float64
# Coupon_Status           object
# GST                    float64
# Date                    object
# Offline_Spend          float64
# Online_Spend           float64
# Month                    int64
# Coupon_Code             object
# Discount_pct           float64
# Payment_Status          object
# Delivery_Days           object
# Customer_Rating        float64
# Return_Status           object
# Customer_City           object
# Discount_Percent        object
# Order_Priority          object
# Support_Calls           object
# Membership              object
# ...

# %%
# 8.Display summary statistics
df.describe()
# Out:
#          Unnamed: 0    CustomerID  Tenure_Months  Transaction_ID  \
# count  20000.000000  20000.000000   20000.000000    20000.000000
# mean    9999.500000  15384.448800      26.419000    31757.398950
# std     5773.647028   1790.469818      13.522188    10442.150226
# min        0.000000  12347.000000       2.000000    16679.000000
# 25%     4999.750000  13819.000000      15.000000    22285.000000
# 50%     9999.500000  15311.000000      27.000000    34498.500000
# 75%    14999.250000  17114.000000      38.000000    36871.000000
# max    19999.000000  18260.000000      50.000000    48497.000000
#
#            Quantity     Avg_Price  Delivery_Charges           GST  \
# count  20000.000000  20000.000000       20000.00000  20000.000000
# mean       4.403900     56.511256          11.07499      0.134707
# std       21.192688     63.316612          20.61016      0.044485
# min        1.000000      0.390000           0.00000      0.050000
# ...

# %%
# 9.Count unique value in each colums
df.nunique()
# Out:
# Unnamed: 0             20000
# CustomerID               889
# Gender                     2
# Location                   5
# Tenure_Months             49
# Transaction_ID         10153
# Transaction_Date         154
# Product_SKU             1012
# Product_Description      385
# Product_Category          20
# Quantity                 111
# Avg_Price                457
# Delivery_Charges         185
# Coupon_Status              3
# GST                        4
# Date                     154
# Offline_Spend             11
# Online_Spend             154
# Month                      5
# Coupon_Code                5
# Discount_pct               3
# Payment_Status             5
# Delivery_Days              7
# Customer_Rating            5
# Return_Status              4
# Customer_City              5
# Discount_Percent           6
# Order_Priority             5
# Support_Calls              6
# Membership                 4
# dtype: int64

# %%
# 10. Identify columns with missing value .
df.isnull()
# Out:
#        Unnamed: 0  CustomerID  Gender  Location  Tenure_Months  \
# 0           False       False   False     False          False
# 1           False       False   False     False          False
# 2           False       False   False     False          False
# 3           False       False   False     False          False
# 4           False       False   False     False          False
# ...           ...         ...     ...       ...            ...
# 19995       False       False   False     False          False
# 19996       False       False   False     False          False
# 19997       False       False   False     False          False
# 19998       False       False   False     False          False
# 19999       False       False   False     False          False
#
#        Transaction_ID  Transaction_Date  Product_SKU  Product_Description  \
# 0               False             False        False                False
# ...

# %%
# PART-3 Missing value Handling(6 question)
# 11. Count missing value in each columns
df.isnull().sum()
# Out:
# Unnamed: 0                0
# CustomerID                0
# Gender                    0
# Location                  0
# Tenure_Months             0
# Transaction_ID            0
# Transaction_Date          0
# Product_SKU               0
# Product_Description       0
# Product_Category          0
# Quantity                  0
# Avg_Price                 0
# Delivery_Charges          0
# Coupon_Status             0
# GST                       0
# Date                      0
# Offline_Spend             0
# Online_Spend              0
# Month                     0
# Coupon_Code            3356
# Discount_pct             83
# Payment_Status         3252
# Delivery_Days          2395
# Customer_Rating        4988
# Return_Status          4076
# Customer_City          3421
# Discount_Percent       2849
# Order_Priority         3356
# Support_Calls          2856
# Membership             6717
# dtype: int64

# %%
# 12. Replace missing value in Customer_Rating with mean
df['Customer_Rating'].fillna(df['Customer_Rating'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_1419/3844716144.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Customer_Rating'].fillna(df['Customer_Rating'].mean(), inplace=True)

# %%
# 13.	Replace missing values in Payment_Status with "Unknown".
df['Payment_Status'].fillna('Unknown',inplace=True)
# Out:
# /tmp/ipykernel_1419/1576518524.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Payment_Status'].fillna('Unknown',inplace=True)

# %%
#14.	Fill missing values in Delivery_Days using median.
df['Delivery_Days'].fillna(df['Delivery_Days'],inplace=True)

# %%
#15.	Replace missing Coupon_Code with "No Coupon".
df['Coupon_Code'].fillna('No Coupon',inplace=True)
# Out:
# /tmp/ipykernel_1419/640160943.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Coupon_Code'].fillna('No Coupon',inplace=True)

# %%
#16.	Verify that missing values are handled.
df.isnull().sum()
# Out:
# Unnamed: 0                0
# CustomerID                0
# Gender                    0
# Location                  0
# Tenure_Months             0
# Transaction_ID            0
# Transaction_Date          0
# Product_SKU               0
# Product_Description       0
# Product_Category          0
# Quantity                  0
# Avg_Price                 0
# Delivery_Charges          0
# Coupon_Status             0
# GST                       0
# Date                      0
# Offline_Spend             0
# Online_Spend              0
# Month                     0
# Coupon_Code               0
# Discount_pct             83
# Payment_Status            0
# Delivery_Days          2395
# Customer_Rating           0
# Return_Status          4076
# Customer_City          3421
# Discount_Percent       2849
# Order_Priority         3356
# Support_Calls          2856
# Membership             6717
# dtype: int64

# %%
#Part 4 – String Cleaning (6 Questions)
#17.	Remove leading and trailing spaces in all string columns.
df.columns.str.strip()
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'Gender', 'Location', 'Tenure_Months',
#        'Transaction_ID', 'Transaction_Date', 'Product_SKU',
#        'Product_Description', 'Product_Category', 'Quantity', 'Avg_Price',
#        'Delivery_Charges', 'Coupon_Status', 'GST', 'Date', 'Offline_Spend',
#        'Online_Spend', 'Month', 'Coupon_Code', 'Discount_pct',
#        'Payment_Status', 'Delivery_Days', 'Customer_Rating', 'Return_Status',
#        'Customer_City', 'Discount_Percent', 'Order_Priority', 'Support_Calls',
#        'Membership'],
#       dtype='object')

# %%
#18.	Convert Payment_Status to lowercase.
df['Payment_Status'].str.lower()
# Out:
# 0        pending
# 1        unknown
# 2        unknown
# 3           paid
# 4        pending
#           ...
# 19995    unknown
# 19996       paid
# 19997      paid
# 19998    pending
# 19999    unknown
# Name: Payment_Status, Length: 20000, dtype: object

# %%
#19.	Standardize values in Customer_City.
df['Customer_City'].str.lower()
# Out:
# 0          unknown
# 1              NaN
# 2           mumbai
# 3         chennai
# 4         chennai
#            ...
# 19995          NaN
# 19996      unknown
# 19997       mumbai
# 19998          NaN
# 19999      chennai
# Name: Customer_City, Length: 20000, dtype: object

# %%
#20.	Clean Coupon_Code (remove extra spaces, make uppercase).
df['Coupon_Code'].str.upper()
# Out:
# 0          UNKNOWN
# 1             NONE
# 2          NEWUSER
# 3          SALE20
# 4        NO COUPON
#            ...
# 19995      UNKNOWN
# 19996    NO COUPON
# 19997      UNKNOWN
# 19998         NONE
# 19999      SALE20
# Name: Coupon_Code, Length: 20000, dtype: object

# %%
#21.	Replace "unknown" values with NaN.
import numpy as np
df.replace('Unknown',np.nan,inplace=True)

# %%
#22.  " Replace NONE" and "none" with NaN.
df.replace(['NONE', 'none'], np.nan, inplace=True)

# %%
#Part 5 – Data Type Cleaning (6 Questions)
df['Delivery_Days'] = df['Delivery_Days'].str.replace('days', '')

# %%
#24.	Convert Discount_Percent to numeric (remove %).
df['Discount_Percent']=df['Discount_Percent'].str.replace('%', '')

# %%
#25.	Convert Support_Calls to numeric (remove "calls").
df['Support-Calls']=df['Support_Calls'].str.replace('calls', '')

# %%
#26.	Convert Customer_Rating to numeric.
df['Customer_Rating'] = pd.to_numeric(df['Customer_Rating'])

# %%
#27.	Handle invalid numeric values.
df['Customer_Rating'] = pd.to_numeric(df['Customer_Rating'], errors='coerce')

# %%
#28.	Verify updated data types.
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0  CustomerID Gender       Location  Tenure_Months  \
# 0               0     17850.0      M        Chicago           12.0
# 1               1     17850.0      M        Chicago           12.0
# 2               2     17850.0      M        Chicago           12.0
# 3               3     17850.0      M        Chicago           12.0
# 4               4     17850.0      M        Chicago           12.0
# ...           ...         ...    ...            ...            ...
# 19995       19995     13854.0      F        Chicago           44.0
# 19996       19996     13854.0      F        Chicago           44.0
# 19997       19997     17790.0      F  Washington DC           34.0
# 19998       19998     12370.0      F       New York           21.0
# 19999       19999     17404.0      F     New Jersey           11.0
#
#        Transaction_ID Transaction_Date     Product_SKU  \
# 0             16679.0       2019-01-01  GGOENEBJ079499
# ...

# %%
#Part 6 – Duplicate Handling (4 Questions)
#29.	Check for duplicate rows.
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Length: 20000, dtype: bool

# %%
#30.	Count duplicate records.
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#31.	Remove duplicate rows.
df.drop_duplicates(inplace=True)

# %%
#32.	Display dataset shape after removal.
df.shape
# Out:
# (20000, 31)

# %%
#Part 7 – Order & Sales Analysis (6 Questions)
#33.	Count total number of orders.
len(df)
# Out:
# 20000

# %%
#34.	Find number of orders by Payment_Status.
df['Payment_Status'].value_counts()
# Out:
# Payment_Status
# FAILED     3430
#  paid      3406
# unknown    3354
# Pending    3337
# Paid       3221
# Name: count, dtype: int64

# %%
#35.	Identify most common payment method/status.
df['Payment_Status'].mode()
# Out:
# 0    FAILED
# Name: Payment_Status, dtype: object

# %%
#36.	Find total number of returned orders.
df[df['Return_Status'] == 'Yes']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, CustomerID, Gender, Location, Tenure_Months, Transaction_ID, Transaction_Date, Product_SKU, Product_Description, Product_Category, Quantity, Avg_Price, Delivery_Charges, Coupon_Status, GST, Date, Offline_Spend, Online_Spend, Month, Coupon_Code, Discount_pct, Payment_Status, Delivery_Days, Customer_Rating, Return_Status, Customer_City, Discount_Percent, Order_Priority, Support_Calls, Membership, Support-Calls]
# Index: []
#
# [0 rows x 31 columns]

# %%
#37.	Calculate return percentage.
df['Return_Status'].value_counts(normalize=True)
# Out:
# Return_Status
#  returned       0.336709
# Not Returned    0.335527
# Returned        0.327764
# Name: proportion, dtype: float64

# %%
#38.	Count orders by Order_Priority.
df['Order_Priority'].value_counts()
# Out:
# Order_Priority
# High       3396
# unknown    3344
# Low        3335
#  high      3312
# Medium     3257
# Name: count, dtype: int64

# %%
#Part 8 – Customer Analysis (5 Questions)
#39.	Count number of customers by Customer_City.
df['Customer_City'].value_counts()
# Out:
# Customer_City
# Mumbai       3403
# Chennai      3315
# Delhi        3284
#  chennai     3265
# Name: count, dtype: int64

# %%
#40.	Find city with highest orders.
df['Customer_City'].mode()
# Out:
# 0    Mumbai
# Name: Customer_City, dtype: object

# %%
#41.	Find average Customer_Rating.
df['Customer_Rating'].mean()
# Out:
# np.float64(3.175792699173994)

# %%
#42.	Identify customers with rating less than 3.
df[df['Customer_Rating']>300]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, CustomerID, Gender, Location, Tenure_Months, Transaction_ID, Transaction_Date, Product_SKU, Product_Description, Product_Category, Quantity, Avg_Price, Delivery_Charges, Coupon_Status, GST, Date, Offline_Spend, Online_Spend, Month, Coupon_Code, Discount_pct, Payment_Status, Delivery_Days, Customer_Rating, Return_Status, Customer_City, Discount_Percent, Order_Priority, Support_Calls, Membership, Support-Calls]
# Index: []
#
# [0 rows x 31 columns]

# %%
#43.	Count customers by Membership type.
df['Membership'].dtypes
# Out:
# dtype('O')

# %%
#Part 9 – Delivery Analysis (5 Questions)
#44.	Find average Delivery_Days.
df['Delivery_Days'] = pd.to_numeric(df['Delivery_Days'], errors='coerce')

# %%
#45.	Identify orders with delivery time > 7 days.
df[df['Delivery_Days']>7]
# Out:
#        Unnamed: 0  CustomerID Gender    Location  Tenure_Months  \
# 1               1     17850.0      M     Chicago           12.0
# 8               8     17850.0      M     Chicago           12.0
# 9               9     17850.0      M     Chicago           12.0
# 18             18     17850.0      M     Chicago           12.0
# 29             29     14688.0      F    New York           46.0
# ...           ...         ...    ...         ...            ...
# 19944       19944     13078.0      F  California           28.0
# 19947       19947     17912.0      M  New Jersey            7.0
# 19959       19959     12867.0      M     Chicago           32.0
# 19967       19967     13846.0      F  New Jersey            4.0
# 19984       19984     15194.0      M     Chicago           33.0
#
#        Transaction_ID Transaction_Date     Product_SKU  \
# 1             16680.0       2019-01-01  GGOENEBJ079499
# 8             16704.0       2019-01-01  GGOENEBJ079499
# ...

# %%
#46.	Count delayed orders.
(df['Delivery_Days'] > 7)
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: Delivery_Days, Length: 20000, dtype: bool

# %%
#47.	Compare delivery time by Order_Priority.
Order_Priority=df.groupby('Order_Priority')['Delivery_Days'].mean()
print(Order_Priority)
# Out:
# Order_Priority
#  high      4.559921
# High       4.660594
# Low        4.633186
# Medium     4.657285
# unknown    4.644612
# Name: Delivery_Days, dtype: float64

# %%
#48.	Find fastest delivery category.
df.groupby('Order_Priority')['Delivery_Days'].min()
# Out:
# Order_Priority
#  high      1.0
# High       1.0
# Low        1.0
# Medium     1.0
# unknown    1.0
# Name: Delivery_Days, dtype: float64

# %%
#Part 10 – Discount & Coupon Analysis (5 Questions)
#49.	Find average Discount_Percent.
df['Discount_Percent'] = pd.to_numeric(df['Discount_Percent'], errors='coerce')

# %%
#50.	Identify orders with highest discount.
df['Discount_Percent'].max()
# Out:
# 25.0

# %%
#51.	Count how many orders used coupons.
df['Coupon_Status'].count()
# Out:
# np.int64(20000)

# %%
#52.	Find most used Coupon_Code.
df['Coupon_Code'].value_counts().idxmax()
# Out:
# 'unknown'

# %%
#53.	Compare price before and after discount (if available).
df['Discounted_Price'] = df['Avg_Price'] - (df['Avg_Price'] * df['Discount_pct'] / 100)

# %%
#Part 11 – Support & Service Analysis (4 Questions)
#54.	Find average Support_Calls per order.
df['Support_Calls'] = pd.to_numeric(
    df['Support_Calls'].str.replace('calls', '', case=False).str.strip(),
    errors='coerce'
)

# %%
#55.	Identify orders with more than 2 support calls.
df[df['Support_Calls']>2]
# Out:
#        Unnamed: 0  CustomerID Gender    Location  Tenure_Months  \
# 0               0     17850.0      M     Chicago           12.0
# 1               1     17850.0      M     Chicago           12.0
# 3               3     17850.0      M     Chicago           12.0
# 19             19     17850.0      M     Chicago           12.0
# 22             22     17850.0      M     Chicago           12.0
# ...           ...         ...    ...         ...            ...
# 19993       19993     16013.0      M    New York           31.0
# 19994       19994     16013.0      M    New York           31.0
# 19995       19995     13854.0      F     Chicago           44.0
# 19998       19998     12370.0      F    New York           21.0
# 19999       19999     17404.0      F  New Jersey           11.0
#
#        Transaction_ID Transaction_Date     Product_SKU  \
# 0             16679.0       2019-01-01  GGOENEBJ079499
# 1             16680.0       2019-01-01  GGOENEBJ079499
# ...

# %%
#56.	Find relation between Support_Calls and Return_Status.
df['Support_Calls'] = pd.to_numeric(df['Support_Calls'], errors='coerce')

# %%
#57.	Identify problematic orders (high calls + returns)
df[df['Support_Calls']>2]
# Out:
#        Unnamed: 0  CustomerID Gender    Location  Tenure_Months  \
# 0               0     17850.0      M     Chicago           12.0
# 1               1     17850.0      M     Chicago           12.0
# 3               3     17850.0      M     Chicago           12.0
# 19             19     17850.0      M     Chicago           12.0
# 22             22     17850.0      M     Chicago           12.0
# ...           ...         ...    ...         ...            ...
# 19993       19993     16013.0      M    New York           31.0
# 19994       19994     16013.0      M    New York           31.0
# 19995       19995     13854.0      F     Chicago           44.0
# 19998       19998     12370.0      F    New York           21.0
# 19999       19999     17404.0      F  New Jersey           11.0
#
#        Transaction_ID Transaction_Date     Product_SKU  \
# 0             16679.0       2019-01-01  GGOENEBJ079499
# 1             16680.0       2019-01-01  GGOENEBJ079499
# ...

# %%
#Part 12 – Final Output (4 Questions)
#58.	Save cleaned dataset as clean_online_shopping.csv.
df.to_csv('clean_online_shopping.csv', index=False)

# %%
#59.	Export analysis results to CSV.
df.to_csv('analysis_result.csv',index=False)

# %%
#60.	Display final dataset shape.
print("Final Dataset Shape:",df.shape)
# Out:
# Final Dataset Shape: (20000, 32)

# %%
# Identify problematic orders(high call + return).
problematic_orders=df[(df['Support_Calls']>2)&(df['Return_Status'] == 'Returned')]
print(problematic_orders)
# Out:
#        Unnamed: 0  CustomerID Gender    Location  Tenure_Months  \
# 24             24     13047.0      M  California           43.0
# 43             43     17511.0      F     Chicago           25.0
# 180           180     17920.0      F  California           18.0
# 212           212     14606.0      F     Chicago           33.0
# 239           239     15694.0      F    New York           41.0
# ...           ...         ...    ...         ...            ...
# 19943       19943     16817.0      M  California           20.0
# 19965       19965     13846.0      F  New Jersey            4.0
# 19974       19974     13846.0      F  New Jersey            4.0
# 19975       19975     13846.0      F  New Jersey            4.0
# 19985       19985     15194.0      M     Chicago           33.0
#
#        Transaction_ID Transaction_Date     Product_SKU  \
# 24            16684.0       2019-01-01  GGOENEBQ079199
# 43            16826.0       2019-01-03  GGOENEBJ079499
# ...

# %%
# Save cleaned data set.
df.to_csv('/content/clean_online_shopping.csv',index=False)

# %%
#export analysis to csv.
df.to_csv('/content/analysis_result.csv',index=False)

# %%
#Display Final dataset shape
df.shape
# Out:
# (20000, 32)

# %%
from google.colab import files
files.download('/content/clean_online_shopping.csv')
